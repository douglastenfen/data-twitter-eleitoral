# %% [markdown]
# <a href="https://colab.research.google.com/github/douglastenfen/data-twitter-eleitoral/blob/main/Etapa_3_EDA%2C_Storytelling_e_Visualiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Etapa 3 - EDA, Storytelling e Visualização

# %%
import pandas as pd

import re

# %%
dataframe_final_candidatos = pd.read_csv('dataframe_final_candidatos.csv')

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet']

# %%
dataframe_final_candidatos.head()

# %%
def limpeza_do_texto(tweet):
  tweet = tweet.lower()
  tweet = re.sub('\n', '', tweet)
  tweet = re.sub('@[^\s]+', '', tweet)
  tweet = re.sub('\B#\S+', '', tweet)
  tweet = re.sub('https?://\S+|www\.\S+', '', tweet)
  return tweet

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet'].apply(lambda i:limpeza_do_texto(i))

# %%
dataframe_final_candidatos.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-07-30 00:05:44+00:00  1553169938575249408
# 1  2022-07-30 00:05:44+00:00  1553169937178497025
# 2  2022-07-30 00:05:44+00:00  1553169937073594368
# 3  2022-07-30 00:15:50+00:00  1553172478918365184
# 4  2022-07-30 00:15:49+00:00  1553172477689331713
#
#                                                Tweet  Candidato  \
# 0   @CentralEleicoes Fora Bolsonaro. É Lula e Rafael       Lula
# 1  eu sonhei que conhecia o presidente lula (????...       Lula
# 2  @LulaOficial LADRÃO! EX-PRESIDIARIO! O inferno...       Lula
# 3                               @jairbolsonaro 👏👏👏😎👊  Bolsonaro
# 4  @emer_choko @youssefhasup @citizenhonesto @kim...  Bolsonaro
#
#                                          Tweet_limpo
# 0                    fora bolsonaro. é lula e rafael
# 1  eu sonhei que conhecia o presidente lula (????...
# 2   ladrão! ex-presidiario! o inferno é o seu lug...
# 3                                              👏👏👏😎👊
# 4      mais um malabarismo mental, a hipocrisia d...

# %%
dataframe_final_candidatos.to_csv('dataframa_final_candidatos_pronto_para_sentimento.csv', sep=',', index=False)
